# %% [markdown]
# # Philadelphia Project

# %% [markdown]
# ## Chinese Grocery Stores

# %%
#importing the data from Yelp API

import argparse
import json
import pprint
import requests
import sys
import urllib

from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode 

import pandas as pd
from pandas.io.json import json_normalize


api_key = "BeSq_z6_GWR16ulkLnI4ReGlT2KRL3WFUaMv03PTab_OIxey1IiUSwmxgVgd5aXoU3fdZR3Vnb5syMsNKUIuOzbmZZwmiOOW-izjFTHl731-VQltKUjmaCtXfa7YW3Yx"

API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'

grocery = 'chinese grocery store'
DEFAULT_LOCATION = 'Philadelphia, PA'

#edit to allow for number of results wanted 
SEARCH_LIMIT = 50;

url_params_grocery = {
    'term': grocery.replace(' ', '+'),
    'location': DEFAULT_LOCATION.replace(' ', '+'),
    'limit': SEARCH_LIMIT
}

url = '{0}{1}'.format(API_HOST, quote(SEARCH_PATH.encode('utf8')))

headers = {
    'Authorization': 'Bearer %s' % api_key,
}

response_grocery = requests.request('GET', url, headers=headers, params=url_params_grocery)
groc = response_grocery.json()
total_count = groc['total']
total_count


df = pd.DataFrame.from_dict(json_normalize(groc['businesses']), orient='columns')

final_grocery = df[['name', 'coordinates.latitude', 'coordinates.longitude', 'categories']]

to_list = pd.DataFrame(df['categories'].values.tolist())
holder = to_list[0].values.tolist()
split = pd.DataFrame(holder)
finalsplit = split[['title']]
final_grocery['categories'] = finalsplit

print("Total number of grocery stores in the area: " + str(total_count))

final_grocery.column = final_grocery.columns = ['grocery store', 'latitude', 'longitude', 'categories']
final_grocery.to_csv('chinese_grocery_store_pp.csv', encoding='utf-8', index=False)
final_grocery
# Out:
# Total number of grocery stores in the area: 540
# /Users/chiragnarayanakere/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                              grocery store   latitude  longitude  \
# 0                      Heng Fa Food Market  39.954418 -75.156356
# 1                 1st Oriental Supermarket  39.934544 -75.153565
# 2                         Asia Supermarket  39.954957 -75.157544
# 3                  Hung Vuong Super Market  39.936749 -75.162758
# 4                            Gong's Market  40.044170 -75.530140
# 5                  Great World Supermarket  39.953780 -75.155920
# 6                     Spring Garden Market  39.960526 -75.145470
# 7                     Sue's Produce Market  39.951250 -75.170690
# 8                  Reading Terminal Market  39.953341 -75.158855
# 9                                    Hmart  39.907780 -74.977150
# 10                      Whole Foods Market  39.942914 -75.157785
# 11                            Mai's Garden  40.220455 -74.871794
# 12                              Assi Plaza  40.225450 -75.254720
# 13                      Fu-Wah Mini Market  39.948300 -75.217060
# 14                 Iovine Brothers Produce  39.953016 -75.159517
# 15                            Trader Joe's  39.954282 -75.176133
# 16  Chung May Chinese & American Food Corp  39.955658 -75.156532
# 17               Seng Hong Oriental Market  40.027650 -75.146150
# 18                               Tuck Hing  39.956108 -75.155937
# 19                                   Hmart  40.063000 -75.136780
# 20                                   Hmart  39.961307 -75.263099
# 21                                    Aldi  39.978640 -75.270690
# 22                    Sun Seng Supermarket  39.935716 -75.066271
# 23                       Big 8 Supermarket  39.939248 -75.170307
# 24                           Bell's Market  40.068352 -75.051423
# 25                             Tasty Place  39.954957 -75.157545
# 26              The Fresh Grocer of Walnut  39.954466 -75.202941
# 27                            Trader Joe's  39.889539 -74.923807
# 28                        Usha Food Market  40.044663 -75.529633
# 29                          Di Bruno Bros.  39.951760 -75.170027
# 30         The Fresh Grocer of Grays Ferry  39.939315 -75.193873
# 31       The Fresh Grocer of Monument Road  40.002340 -75.213780
# 32                     ShopRite - Parkside  39.979546 -75.224838
# 33                        Chai Hong Market  39.921570 -75.158707
# 34                          Food & Friends  39.948300 -75.174140
# 35                           Oregon Market  39.913826 -75.153595
# 36                           Su Xing House  39.950215 -75.166346
# 37                                   Hmart  40.165890 -74.875830
# 38                             Han Dynasty  39.956711 -75.197103
# 39               Heung Fa Chun Sweet House  39.953906 -75.156261
# 40                      Asian Bamboo House  40.050018 -74.989493
# 41                        Swarthmore CO-OP  39.902372 -75.348925
# 42                      Beijing Restaurant  39.951004 -75.198066
# 43                  Hue Fusion Food Market  39.979339 -75.161205
# 44                     Tai Lake Restaurant  39.954660 -75.156340
# 45                            Lee's Market  40.089259 -75.291011
# 46       The Fresh Grocer - Progress Plaza  39.976663 -75.157783
# 47                          Dim Sum Garden  39.955399 -75.156727
# 48                          Produce Market  39.954740 -75.156590
# 49                  ShopRite of Brookhaven  39.880111 -75.395955
#
#             categories
# 0              Grocery
# 1        Imported Food
# 2              Grocery
# 3              Grocery
# 4              Grocery
# 5              Grocery
# 6              Grocery
# 7              Grocery
# 8       Public Markets
# 9               Korean
# 10             Grocery
# 11             Grocery
# 12              Korean
# 13  Convenience Stores
# 14    Fruits & Veggies
# 15             Grocery
# 16             Grocery
# 17             Grocery
# 18             Grocery
# 19             Grocery
# 20             Grocery
# 21             Grocery
# 22             Grocery
# 23             Grocery
# 24               Delis
# 25             Chinese
# 26             Grocery
# 27             Grocery
# 28             Grocery
# 29        Cheese Shops
# 30             Grocery
# 31             Grocery
# 32             Grocery
# 33             Grocery
# 34             Grocery
# 35             Grocery
# 36             Chinese
# 37             Grocery
# 38            Szechuan
# 39             Chinese
# 40             Chinese
# 41             Grocery
# 42             Chinese
# 43               Delis
# 44             Chinese
# 45    Fruits & Veggies
# 46             Grocery
# 47             Dim Sum
# 48    Fruits & Veggies
# 49             Grocery

# %% [markdown]
# ## Chinese Food

# %%
#importing the data from Yelp API

import argparse
import json
import pprint
import requests
import sys
import urllib

from urllib.error import HTTPError
from urllib.parse import quote
from urllib.parse import urlencode 

import pandas as pd
from pandas.io.json import json_normalize


api_key = "BeSq_z6_GWR16ulkLnI4ReGlT2KRL3WFUaMv03PTab_OIxey1IiUSwmxgVgd5aXoU3fdZR3Vnb5syMsNKUIuOzbmZZwmiOOW-izjFTHl731-VQltKUjmaCtXfa7YW3Yx"

API_HOST = 'https://api.yelp.com'
SEARCH_PATH = '/v3/businesses/search'
BUSINESS_PATH = '/v3/businesses/'

food = 'chinese food'
DEFAULT_LOCATION = 'Philadelphia, PA'

#edit to allow for number of results wanted 
SEARCH_LIMIT = 50;

url_params_food = {
    'term': food.replace(' ', '+'),
    'location': DEFAULT_LOCATION.replace(' ', '+'),
    'limit': SEARCH_LIMIT
}

url = '{0}{1}'.format(API_HOST, quote(SEARCH_PATH.encode('utf8')))

headers = {
    'Authorization': 'Bearer %s' % api_key,
}

response_food = requests.request('GET', url, headers=headers, params=url_params_food)
chinese_food = response_food.json()
total_count = chinese_food['total']


df = pd.DataFrame.from_dict(json_normalize(chinese_food['businesses']), orient='columns')

final_food = df[['name', 'coordinates.latitude', 'coordinates.longitude', 'categories']]

to_list = pd.DataFrame(df['categories'].values.tolist())
holder = to_list[0].values.tolist()
split = pd.DataFrame(holder)
finalsplit = split[['title']]
final_food['categories'] = finalsplit

print("Total number of grocery stores in the area: " + str(total_count))

final_food.column = final_food.columns = ['food', 'latitude', 'longitude', 'categories']
final_food.to_csv('chinese_food_pp.csv', encoding='utf-8', index=False)
final_food
# Out:
# Total number of grocery stores in the area: 1500
# /Users/chiragnarayanakere/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#                                    food   latitude  longitude  \
# 0                           Han Dynasty  39.948398 -75.143584
# 1      Nan Zhou Hand Drawn Noodle House  39.955401 -75.156901
# 2                        Dim Sum Garden  39.955399 -75.156727
# 3                               Dan Dan  39.950249 -75.167595
# 4                              Jane G's  39.951833 -75.173352
# 5                                Sampan  39.949531 -75.162157
# 6            Sang Kee Peking Duck House  39.956390 -75.154330
# 7                  Ting Wong Restaurant  39.954709 -75.156146
# 8                             China Wok  40.029217 -75.223457
# 9                            Shan Chuan  40.009220 -75.194070
# 10                        Su Xing House  39.950215 -75.166346
# 11                          China House  39.918586 -75.183686
# 12                          Han Dynasty  39.956711 -75.197103
# 13                             Spice 28  39.950352 -75.161583
# 14                          Han Dynasty  40.025452 -75.223930
# 15                       Shiao Lan Kung  39.955160 -75.155430
# 16           Xinying Chinese Restaurant  39.983144 -75.114942
